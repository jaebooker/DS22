# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Lambda, Input
from keras.optimizers import SGD
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np
import pandas as pd

# %%
bdf = load_boston()
bdfs = pd.DataFrame(bdf.data)

# %%
scaler = StandardScaler()
X = bdfs.values
y = bdf.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.4,random_state=0)
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
model = Sequential()
model.add(Dense(1,input_dim=13,activation="linear"))
model.compile(optimizer="adam",loss="mse",metrics=["mse","mae"])
model.fit(X_train, y_train, epochs=400,batch_size=1,verbose=1)
# Out:
# Epoch 1/400
# 303/303 [==============================] - 1s 2ms/step - loss: 613.3007 - mean_squared_error: 613.3007 - mean_absolute_error: 22.6294
# Epoch 2/400
# 303/303 [==============================] - 0s 1ms/step - loss: 593.8426 - mean_squared_error: 593.8426 - mean_absolute_error: 22.3416
# Epoch 3/400
# 303/303 [==============================] - 0s 1ms/step - loss: 575.2257 - mean_squared_error: 575.2257 - mean_absolute_error: 22.0747
# Epoch 4/400
# 303/303 [==============================] - 1s 2ms/step - loss: 557.7147 - mean_squared_error: 557.7147 - mean_absolute_error: 21.7944
# Epoch 5/400
# 303/303 [==============================] - 0s 2ms/step - loss: 541.0840 - mean_squared_error: 541.0840 - mean_absolute_error: 21.5207
# Epoch 6/400
# 303/303 [==============================] - 1s 2ms/step - loss: 525.3283 - mean_squared_error: 525.3283 - mean_absolute_error: 21.2513
# Epoch 7/400
# ...

# %%
regress = LinearRegression()
regress.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
loss, mse, mae = model.evaluate(X_test,y_test, verbose=0)
sklearn_mse = mean_squared_error(regress.predict(X_test),y_test)

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6761247531103799

# %%
print(mse)
# Out:
# 26.79437800816127

# %%
print(loss)
# Out:
# 26.79437800816127

# %%
sklearn_mse
# Out:
# 26.708092645550924

# %%
y_train_one_hot = np_utils.to_categorical(y_train)
y_test_one_hot = np_utils.to_categorical(y_test)

# %%
print(r2_score(model.predict(X_test),y_test))
# Out:
# 0.584252842914565

# %%
print(r2_score(regress.predict(X_test),y_test))
# Out:
# 0.5865827889127377
